# %% [markdown]
# <a href="https://colab.research.google.com/github/douglasmasho/MedAlgo/blob/main/Survival.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
import glob

# Mount Google Drive
drive.mount('/content/drive')

# data_dir = '/content/drive/MyDrive/BRATS/MICCAI_BraTS_2019_Data_Training'

# survival_data = os.path.join(data_dir, "survival_data.csv")
# hgg_images = os.path.join(data_dir, "HGG")
# lgg_images = os.path.join(data_dir, "LGG")

# print(hgg_images)
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import pandas as pd
import nibabel as nib
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras import layers, models
import tensorflow as tf

# Load survival data
survival_data = pd.read_csv('/content/drive/MyDrive/BRATS/MICCAI_BraTS_2019_Data_Training/processed_survival_data.csv')

# Filter subjects with non-NA Age and Survival
survival_data = survival_data.dropna(subset=['Age', 'Survival', 'Status'])

# Process the survival data
def process_survival(survival):
    if 'ALIVE' in survival:
        days = int(survival.split('(')[1].split()[0])
        return days
    else:
        return -int(survival)

survival_data['Survival'] = survival_data['Survival'].apply(process_survival)

# Define a function to get 2D slices from 3D MRI images
def get_2d_slices(img_3d):
    slices = []
    for i in range(img_3d.shape[-1]):
        slice_2d = img_3d[:, :, i]
        # Add a channel dimension (height, width, channels)
        slice_2d = np.expand_dims(slice_2d, axis=-1)
        slices.append(slice_2d)
    return slices

# Load and preprocess the data
def load_and_preprocess_data(root_dirs, df):
    images = []
    survival_days = []
    statuses = []
    ages = []

    for root_dir in root_dirs:
        for subject_dir in os.listdir(root_dir):
            subject_path = os.path.join(root_dir, subject_dir)
            if os.path.isdir(subject_path):
                img_path = os.path.join(subject_path, f'{subject_dir}_t1ce.nii')
                if os.path.isfile(img_path):
                    # Extract Brats19ID from the subject directory name
                    brats_id = subject_dir
                    if brats_id in df['BraTS19ID'].values:
                        # Get the corresponding survival and age data
                        row = df[df['BraTS19ID'] == brats_id].iloc[0]
                        age = row['Age']
                        survival = row['Survival']
                        status = row['Status']

                        img_3d = nib.load(img_path).get_fdata()
                        slices = get_2d_slices(img_3d)

                        for slice_2d in slices:
                            # Resize the image if needed
                            img_resized = array_to_img(slice_2d, scale=True).resize((64, 64))
                            img_array = img_to_array(img_resized)
                            images.append(img_array)
                            survival_days.append(survival)
                            statuses.append(1 if status == 'alive' else 0)
                            ages.append(age)

    return np.array(images), np.array(ages), np.array(survival_days), np.array(statuses)

# Define directories for both HGG and LGG
hgg_dir = '/content/drive/MyDrive/BRATS/MICCAI_BraTS_2019_Data_Training/HGG'
lgg_dir = '/content/drive/MyDrive/BRATS/MICCAI_BraTS_2019_Data_Training/LGG'
all_dirs = [hgg_dir, lgg_dir]

# Load and preprocess the data
images, ages, survival_days, statuses = load_and_preprocess_data(all_dirs, survival_data)

# Split the dataset into training and validation sets
X_train, X_val, age_train, age_val, y_train, y_val, status_train, status_val = train_test_split(
    images, ages, survival_days, statuses, test_size=0.2, random_state=42
)

# Define the model
def create_model(input_shape):
    inputs = tf.keras.Input(shape=input_shape)
    x = layers.Conv2D(32, (3, 3), activation='relu')(inputs)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(64, (3, 3), activation='relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(128, (3, 3), activation='relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Flatten()(x)
    x = layers.Dense(128, activation='relu')(x)

    age_input = tf.keras.Input(shape=(1,))
    age_dense = layers.Dense(64, activation='relu')(age_input)

    combined = layers.concatenate([x, age_dense])

    # Output layer for survival days
    survival_output = layers.Dense(1, name='survival')(combined)

    # Output layer for status
    status_output = layers.Dense(1, activation='sigmoid', name='status')(combined)

    model = tf.keras.Model(inputs=[inputs, age_input], outputs=[survival_output, status_output])
    model.compile(optimizer='adam',
                  loss={'survival': 'mse', 'status': 'binary_crossentropy'},
                  metrics={'status': 'accuracy'})
    return model

# Create and train the model
input_shape = (64, 64, 1)
model = create_model(input_shape)

# Define a callback to save the best model
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    'best_glioma_survival_model.keras',
    monitor='val_status_accuracy',
    save_best_only=True,
    mode='max'
)

history = model.fit(
    [X_train, age_train],
    {'survival': y_train, 'status': status_train},
    epochs=200,
    batch_size=32,
    validation_data=([X_val, age_val], {'survival': y_val, 'status': status_val}),
    callbacks=[checkpoint_callback]
)

# Evaluate the model
results = model.evaluate([X_val, age_val], {'survival': y_val, 'status': status_val})

# Print the results
print("Evaluation Results:")
print(results)
# print(f"Total Loss: {results[0]}")
# print(f"Survival Loss: {results[1]}")
# print(f"Status Loss: {results[2]}")
# print(f"Status Accuracy: {results[3]}")
# print("")
# Save the final model if needed
model.save('glioma_survival_model_with_status.keras')
# Out:
# Epoch 1/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - loss: 157521.1562 - status_accuracy: 0.9875 - val_loss: 129528.3281 - val_status_accuracy: 0.9889
# Epoch 2/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 130219.5547 - status_accuracy: 0.9882 - val_loss: 121136.0938 - val_status_accuracy: 0.9915
# Epoch 3/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 118872.1094 - status_accuracy: 0.9868 - val_loss: 104909.1250 - val_status_accuracy: 0.9865
# Epoch 4/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 97584.2266 - status_accuracy: 0.9847 - val_loss: 91046.1641 - val_status_accuracy: 0.9909
# Epoch 5/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 79708.1797 - status_accuracy: 0.9840 - val_loss: 77931.0859 - val_status_accuracy: 0.9916
# Epoch 6/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 61730.6719 - status_accuracy: 0.9852 - val_loss: 67486.4375 - val_status_accuracy: 0.9916
# Epoch 7/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 50878.9805 - status_accuracy: 0.9880 - val_loss: 60258.8633 - val_status_accuracy: 0.9913
# Epoch 8/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 41717.3867 - status_accuracy: 0.9882 - val_loss: 61520.0234 - val_status_accuracy: 0.9863
# Epoch 9/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 38435.3906 - status_accuracy: 0.9897 - val_loss: 68174.6406 - val_status_accuracy: 0.9930
# Epoch 10/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 35578.4648 - status_accuracy: 0.9914 - val_loss: 52870.9375 - val_status_accuracy: 0.9932
# Epoch 11/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 31290.6426 - status_accuracy: 0.9923 - val_loss: 48441.6562 - val_status_accuracy: 0.9932
# Epoch 12/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 29554.4277 - status_accuracy: 0.9931 - val_loss: 49350.5938 - val_status_accuracy: 0.9860
# Epoch 13/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 27296.8574 - status_accuracy: 0.9944 - val_loss: 44613.2539 - val_status_accuracy: 0.9922
# Epoch 14/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 26008.9219 - status_accuracy: 0.9943 - val_loss: 45350.4023 - val_status_accuracy: 0.9935
# Epoch 15/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 23090.6211 - status_accuracy: 0.9968 - val_loss: 46660.6484 - val_status_accuracy: 0.9947
# Epoch 16/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 24185.6699 - status_accuracy: 0.9962 - val_loss: 43805.3516 - val_status_accuracy: 0.9956
# Epoch 17/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 23593.0977 - status_accuracy: 0.9959 - val_loss: 46494.1367 - val_status_accuracy: 0.9962
# Epoch 18/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 22535.7344 - status_accuracy: 0.9967 - val_loss: 43196.9570 - val_status_accuracy: 0.9962
# Epoch 19/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 20966.3535 - status_accuracy: 0.9970 - val_loss: 41185.5625 - val_status_accuracy: 0.9956
# Epoch 20/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 21193.4883 - status_accuracy: 0.9972 - val_loss: 41179.3945 - val_status_accuracy: 0.9956
# Epoch 21/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 20417.3301 - status_accuracy: 0.9972 - val_loss: 41365.7109 - val_status_accuracy: 0.9941
# Epoch 22/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 20394.7637 - status_accuracy: 0.9974 - val_loss: 41542.0078 - val_status_accuracy: 0.9965
# Epoch 23/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 20100.4043 - status_accuracy: 0.9975 - val_loss: 39854.1914 - val_status_accuracy: 0.9963
# Epoch 24/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 20062.8086 - status_accuracy: 0.9977 - val_loss: 40210.1250 - val_status_accuracy: 0.9968
# Epoch 25/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 18799.1289 - status_accuracy: 0.9976 - val_loss: 38659.7852 - val_status_accuracy: 0.9954
# Epoch 26/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 18272.8496 - status_accuracy: 0.9986 - val_loss: 38873.0117 - val_status_accuracy: 0.9960
# Epoch 27/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 18808.0918 - status_accuracy: 0.9981 - val_loss: 39670.8516 - val_status_accuracy: 0.9959
# Epoch 28/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 19445.6309 - status_accuracy: 0.9974 - val_loss: 38495.6406 - val_status_accuracy: 0.9963
# Epoch 29/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 18726.4102 - status_accuracy: 0.9976 - val_loss: 38338.8828 - val_status_accuracy: 0.9960
# Epoch 30/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 17894.9688 - status_accuracy: 0.9982 - val_loss: 38345.1992 - val_status_accuracy: 0.9960
# Epoch 31/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 17839.3359 - status_accuracy: 0.9967 - val_loss: 38273.1133 - val_status_accuracy: 0.9967
# Epoch 32/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 16784.2793 - status_accuracy: 0.9974 - val_loss: 37740.2188 - val_status_accuracy: 0.9967
# Epoch 33/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 17629.6738 - status_accuracy: 0.9976 - val_loss: 38012.8711 - val_status_accuracy: 0.9965
# Epoch 34/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 17084.5000 - status_accuracy: 0.9982 - val_loss: 38680.0664 - val_status_accuracy: 0.9965
# Epoch 35/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 17778.4004 - status_accuracy: 0.9980 - val_loss: 37027.8594 - val_status_accuracy: 0.9951
# Epoch 36/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 17249.6172 - status_accuracy: 0.9977 - val_loss: 38230.7383 - val_status_accuracy: 0.9960
# Epoch 37/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 16766.6680 - status_accuracy: 0.9981 - val_loss: 36075.6406 - val_status_accuracy: 0.9967
# Epoch 38/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 17548.7207 - status_accuracy: 0.9974 - val_loss: 40525.4688 - val_status_accuracy: 0.9951
# Epoch 39/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 16975.8320 - status_accuracy: 0.9979 - val_loss: 35960.4570 - val_status_accuracy: 0.9960
# Epoch 40/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 16696.7871 - status_accuracy: 0.9980 - val_loss: 35790.1094 - val_status_accuracy: 0.9963
# Epoch 41/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 16699.5391 - status_accuracy: 0.9976 - val_loss: 35643.9258 - val_status_accuracy: 0.9968
# Epoch 42/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 16726.1543 - status_accuracy: 0.9969 - val_loss: 38475.5898 - val_status_accuracy: 0.9963
# Epoch 43/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 16953.6426 - status_accuracy: 0.9973 - val_loss: 36668.1250 - val_status_accuracy: 0.9960
# Epoch 44/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 15902.1045 - status_accuracy: 0.9975 - val_loss: 38223.3086 - val_status_accuracy: 0.9963
# Epoch 45/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 16784.1348 - status_accuracy: 0.9968 - val_loss: 37811.4805 - val_status_accuracy: 0.9965
# Epoch 46/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 16749.4395 - status_accuracy: 0.9981 - val_loss: 36144.0586 - val_status_accuracy: 0.9968
# Epoch 47/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 15725.8154 - status_accuracy: 0.9977 - val_loss: 36884.7578 - val_status_accuracy: 0.9948
# Epoch 48/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 15936.2578 - status_accuracy: 0.9973 - val_loss: 35686.0508 - val_status_accuracy: 0.9942
# Epoch 49/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 16814.3223 - status_accuracy: 0.9977 - val_loss: 36065.9062 - val_status_accuracy: 0.9971
# Epoch 50/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 16198.5127 - status_accuracy: 0.9975 - val_loss: 36644.7930 - val_status_accuracy: 0.9956
# Epoch 51/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 15985.0459 - status_accuracy: 0.9976 - val_loss: 35295.6602 - val_status_accuracy: 0.9963
# Epoch 52/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 16498.9980 - status_accuracy: 0.9976 - val_loss: 35144.8516 - val_status_accuracy: 0.9954
# Epoch 53/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14931.5859 - status_accuracy: 0.9987 - val_loss: 35700.4062 - val_status_accuracy: 0.9960
# Epoch 54/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 15013.5771 - status_accuracy: 0.9978 - val_loss: 45285.6523 - val_status_accuracy: 0.9960
# Epoch 55/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 16457.5488 - status_accuracy: 0.9981 - val_loss: 35455.7188 - val_status_accuracy: 0.9965
# Epoch 56/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 15623.8203 - status_accuracy: 0.9981 - val_loss: 36141.4844 - val_status_accuracy: 0.9857
# Epoch 57/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 15877.4033 - status_accuracy: 0.9971 - val_loss: 36358.4258 - val_status_accuracy: 0.9953
# Epoch 58/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 15392.4922 - status_accuracy: 0.9969 - val_loss: 37088.1914 - val_status_accuracy: 0.9960
# Epoch 59/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14849.2607 - status_accuracy: 0.9975 - val_loss: 36732.9336 - val_status_accuracy: 0.9935
# Epoch 60/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 16227.7354 - status_accuracy: 0.9975 - val_loss: 36683.6211 - val_status_accuracy: 0.9962
# Epoch 61/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 15345.7100 - status_accuracy: 0.9977 - val_loss: 35105.5664 - val_status_accuracy: 0.9974
# Epoch 62/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 15095.1084 - status_accuracy: 0.9973 - val_loss: 36901.3867 - val_status_accuracy: 0.9962
# Epoch 63/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 15409.3613 - status_accuracy: 0.9988 - val_loss: 35131.1445 - val_status_accuracy: 0.9965
# Epoch 64/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 14867.8047 - status_accuracy: 0.9972 - val_loss: 35501.5781 - val_status_accuracy: 0.9971
# Epoch 65/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 15532.4131 - status_accuracy: 0.9981 - val_loss: 34938.5391 - val_status_accuracy: 0.9965
# Epoch 66/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14838.6895 - status_accuracy: 0.9976 - val_loss: 34930.3125 - val_status_accuracy: 0.9971
# Epoch 67/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 15136.8984 - status_accuracy: 0.9981 - val_loss: 34371.0234 - val_status_accuracy: 0.9970
# Epoch 68/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 14870.4951 - status_accuracy: 0.9983 - val_loss: 35341.1172 - val_status_accuracy: 0.9965
# Epoch 69/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 15286.0742 - status_accuracy: 0.9976 - val_loss: 35502.1445 - val_status_accuracy: 0.9970
# Epoch 70/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 15775.3604 - status_accuracy: 0.9982 - val_loss: 35278.8398 - val_status_accuracy: 0.9965
# Epoch 71/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 15971.1104 - status_accuracy: 0.9979 - val_loss: 35664.9492 - val_status_accuracy: 0.9957
# Epoch 72/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 16430.5898 - status_accuracy: 0.9972 - val_loss: 35515.2852 - val_status_accuracy: 0.9970
# Epoch 73/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 15617.9365 - status_accuracy: 0.9981 - val_loss: 34516.1484 - val_status_accuracy: 0.9973
# Epoch 74/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 15921.4678 - status_accuracy: 0.9983 - val_loss: 34770.1055 - val_status_accuracy: 0.9965
# Epoch 75/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 14751.4248 - status_accuracy: 0.9977 - val_loss: 34683.2422 - val_status_accuracy: 0.9968
# Epoch 76/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 15411.6729 - status_accuracy: 0.9977 - val_loss: 34715.6172 - val_status_accuracy: 0.9954
# Epoch 77/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 14678.2109 - status_accuracy: 0.9981 - val_loss: 34720.0586 - val_status_accuracy: 0.9970
# Epoch 78/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14946.6738 - status_accuracy: 0.9978 - val_loss: 34564.9727 - val_status_accuracy: 0.9967
# Epoch 79/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14857.3770 - status_accuracy: 0.9977 - val_loss: 34163.4023 - val_status_accuracy: 0.9968
# Epoch 80/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14251.0078 - status_accuracy: 0.9985 - val_loss: 34878.4883 - val_status_accuracy: 0.9959
# Epoch 81/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13386.0371 - status_accuracy: 0.9987 - val_loss: 34350.0391 - val_status_accuracy: 0.9948
# Epoch 82/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14578.9082 - status_accuracy: 0.9982 - val_loss: 34408.7188 - val_status_accuracy: 0.9970
# Epoch 83/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 13697.6650 - status_accuracy: 0.9985 - val_loss: 34770.0781 - val_status_accuracy: 0.9967
# Epoch 84/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 14899.6875 - status_accuracy: 0.9981 - val_loss: 34599.8477 - val_status_accuracy: 0.9967
# Epoch 85/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 15399.2002 - status_accuracy: 0.9981 - val_loss: 34874.2969 - val_status_accuracy: 0.9962
# Epoch 86/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 15092.1650 - status_accuracy: 0.9984 - val_loss: 34329.8594 - val_status_accuracy: 0.9968
# Epoch 87/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 14170.4141 - status_accuracy: 0.9979 - val_loss: 34338.6602 - val_status_accuracy: 0.9963
# Epoch 88/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13894.0303 - status_accuracy: 0.9978 - val_loss: 34107.8125 - val_status_accuracy: 0.9960
# Epoch 89/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14404.9668 - status_accuracy: 0.9979 - val_loss: 34582.1016 - val_status_accuracy: 0.9960
# Epoch 90/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14856.8701 - status_accuracy: 0.9982 - val_loss: 33815.4531 - val_status_accuracy: 0.9967
# Epoch 91/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14008.2500 - status_accuracy: 0.9984 - val_loss: 33668.9844 - val_status_accuracy: 0.9973
# Epoch 92/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 13966.2207 - status_accuracy: 0.9980 - val_loss: 34002.7344 - val_status_accuracy: 0.9967
# Epoch 93/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 14481.3906 - status_accuracy: 0.9987 - val_loss: 34579.2422 - val_status_accuracy: 0.9956
# Epoch 94/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 15174.9121 - status_accuracy: 0.9981 - val_loss: 34797.6953 - val_status_accuracy: 0.9960
# Epoch 95/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14258.4326 - status_accuracy: 0.9984 - val_loss: 35345.9141 - val_status_accuracy: 0.9962
# Epoch 96/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14211.9385 - status_accuracy: 0.9983 - val_loss: 34353.9727 - val_status_accuracy: 0.9963
# Epoch 97/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 15059.1670 - status_accuracy: 0.9983 - val_loss: 34427.4609 - val_status_accuracy: 0.9962
# Epoch 98/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14231.9824 - status_accuracy: 0.9977 - val_loss: 34359.5781 - val_status_accuracy: 0.9967
# Epoch 99/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13696.3418 - status_accuracy: 0.9986 - val_loss: 36320.7188 - val_status_accuracy: 0.9970
# Epoch 100/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 14864.0361 - status_accuracy: 0.9978 - val_loss: 34781.0781 - val_status_accuracy: 0.9919
# Epoch 101/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14320.9902 - status_accuracy: 0.9976 - val_loss: 33684.4297 - val_status_accuracy: 0.9960
# Epoch 102/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14258.9902 - status_accuracy: 0.9983 - val_loss: 33614.8398 - val_status_accuracy: 0.9953
# Epoch 103/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14164.0693 - status_accuracy: 0.9983 - val_loss: 35509.2422 - val_status_accuracy: 0.9963
# Epoch 104/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14282.9443 - status_accuracy: 0.9986 - val_loss: 33956.7969 - val_status_accuracy: 0.9965
# Epoch 105/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14846.4590 - status_accuracy: 0.9981 - val_loss: 34067.5117 - val_status_accuracy: 0.9886
# Epoch 106/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 13932.4141 - status_accuracy: 0.9979 - val_loss: 33937.4414 - val_status_accuracy: 0.9965
# Epoch 107/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 14055.4824 - status_accuracy: 0.9988 - val_loss: 35209.3711 - val_status_accuracy: 0.9960
# Epoch 108/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 14089.9336 - status_accuracy: 0.9982 - val_loss: 34340.7930 - val_status_accuracy: 0.9962
# Epoch 109/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14086.0566 - status_accuracy: 0.9983 - val_loss: 33888.2539 - val_status_accuracy: 0.9858
# Epoch 110/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13843.0391 - status_accuracy: 0.9978 - val_loss: 33410.8125 - val_status_accuracy: 0.9963
# Epoch 111/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14108.8154 - status_accuracy: 0.9978 - val_loss: 33472.0625 - val_status_accuracy: 0.9957
# Epoch 112/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14382.4531 - status_accuracy: 0.9978 - val_loss: 35166.7305 - val_status_accuracy: 0.9967
# Epoch 113/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14907.4766 - status_accuracy: 0.9978 - val_loss: 33558.7539 - val_status_accuracy: 0.9963
# Epoch 114/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14202.2939 - status_accuracy: 0.9984 - val_loss: 35232.7812 - val_status_accuracy: 0.9968
# Epoch 115/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 15488.4600 - status_accuracy: 0.9977 - val_loss: 34070.2461 - val_status_accuracy: 0.9970
# Epoch 116/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 14548.3193 - status_accuracy: 0.9979 - val_loss: 33391.8516 - val_status_accuracy: 0.9965
# Epoch 117/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 15591.8975 - status_accuracy: 0.9974 - val_loss: 33780.0312 - val_status_accuracy: 0.9973
# Epoch 118/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 13590.1240 - status_accuracy: 0.9978 - val_loss: 33408.7266 - val_status_accuracy: 0.9963
# Epoch 119/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14188.8662 - status_accuracy: 0.9981 - val_loss: 33531.8867 - val_status_accuracy: 0.9778
# Epoch 120/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13996.9004 - status_accuracy: 0.9977 - val_loss: 33125.8320 - val_status_accuracy: 0.9967
# Epoch 121/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14202.0996 - status_accuracy: 0.9982 - val_loss: 33671.9531 - val_status_accuracy: 0.9967
# Epoch 122/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 14024.0820 - status_accuracy: 0.9983 - val_loss: 34357.1289 - val_status_accuracy: 0.9954
# Epoch 123/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 13294.0596 - status_accuracy: 0.9989 - val_loss: 34643.3828 - val_status_accuracy: 0.9963
# Epoch 124/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13708.7051 - status_accuracy: 0.9986 - val_loss: 34985.0898 - val_status_accuracy: 0.9950
# Epoch 125/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13504.3115 - status_accuracy: 0.9983 - val_loss: 35695.2383 - val_status_accuracy: 0.9947
# Epoch 126/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13123.6455 - status_accuracy: 0.9985 - val_loss: 33566.0977 - val_status_accuracy: 0.9959
# Epoch 127/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13714.8037 - status_accuracy: 0.9980 - val_loss: 36166.7812 - val_status_accuracy: 0.9957
# Epoch 128/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13975.9316 - status_accuracy: 0.9983 - val_loss: 34179.1992 - val_status_accuracy: 0.9967
# Epoch 129/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 13142.5791 - status_accuracy: 0.9988 - val_loss: 33678.2617 - val_status_accuracy: 0.9963
# Epoch 130/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13744.5684 - status_accuracy: 0.9985 - val_loss: 34664.6562 - val_status_accuracy: 0.9965
# Epoch 131/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 14253.1025 - status_accuracy: 0.9978 - val_loss: 34516.4570 - val_status_accuracy: 0.9954
# Epoch 132/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13436.8496 - status_accuracy: 0.9984 - val_loss: 34036.5977 - val_status_accuracy: 0.9953
# Epoch 133/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13814.3027 - status_accuracy: 0.9976 - val_loss: 33997.0664 - val_status_accuracy: 0.9957
# Epoch 134/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14540.8896 - status_accuracy: 0.9979 - val_loss: 33312.2656 - val_status_accuracy: 0.9962
# Epoch 135/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14692.8379 - status_accuracy: 0.9975 - val_loss: 34190.1602 - val_status_accuracy: 0.9954
# Epoch 136/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 14624.3223 - status_accuracy: 0.9982 - val_loss: 34296.3516 - val_status_accuracy: 0.9898
# Epoch 137/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 12999.5303 - status_accuracy: 0.9985 - val_loss: 35509.7148 - val_status_accuracy: 0.9967
# Epoch 138/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 13860.4082 - status_accuracy: 0.9983 - val_loss: 34580.3906 - val_status_accuracy: 0.9953
# Epoch 139/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 14260.8271 - status_accuracy: 0.9980 - val_loss: 33550.0898 - val_status_accuracy: 0.9965
# Epoch 140/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 14073.5938 - status_accuracy: 0.9982 - val_loss: 34193.1875 - val_status_accuracy: 0.9968
# Epoch 141/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 14287.5439 - status_accuracy: 0.9979 - val_loss: 33561.6250 - val_status_accuracy: 0.9950
# Epoch 142/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13988.4717 - status_accuracy: 0.9981 - val_loss: 34149.0195 - val_status_accuracy: 0.9963
# Epoch 143/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 14662.3369 - status_accuracy: 0.9986 - val_loss: 33591.3867 - val_status_accuracy: 0.9970
# Epoch 144/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14110.5039 - status_accuracy: 0.9982 - val_loss: 34271.2617 - val_status_accuracy: 0.9956
# Epoch 145/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 14204.8076 - status_accuracy: 0.9985 - val_loss: 34381.9023 - val_status_accuracy: 0.9962
# Epoch 146/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 13917.5059 - status_accuracy: 0.9985 - val_loss: 33572.6641 - val_status_accuracy: 0.9960
# Epoch 147/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 14046.0732 - status_accuracy: 0.9982 - val_loss: 33744.8711 - val_status_accuracy: 0.9963
# Epoch 148/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14375.4775 - status_accuracy: 0.9981 - val_loss: 33392.0742 - val_status_accuracy: 0.9968
# Epoch 149/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 13655.8809 - status_accuracy: 0.9980 - val_loss: 34398.6836 - val_status_accuracy: 0.9960
# Epoch 150/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 13671.9941 - status_accuracy: 0.9983 - val_loss: 34362.1094 - val_status_accuracy: 0.9974
# Epoch 151/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 14527.5762 - status_accuracy: 0.9979 - val_loss: 33151.8984 - val_status_accuracy: 0.9967
# Epoch 152/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13330.7031 - status_accuracy: 0.9978 - val_loss: 34006.6406 - val_status_accuracy: 0.9973
# Epoch 153/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 13896.1465 - status_accuracy: 0.9980 - val_loss: 34230.9570 - val_status_accuracy: 0.9962
# Epoch 154/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 14141.7207 - status_accuracy: 0.9983 - val_loss: 34045.8828 - val_status_accuracy: 0.9967
# Epoch 155/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14054.5156 - status_accuracy: 0.9985 - val_loss: 34908.3516 - val_status_accuracy: 0.9971
# Epoch 156/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 14000.1436 - status_accuracy: 0.9989 - val_loss: 34674.6328 - val_status_accuracy: 0.9968
# Epoch 157/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13739.3896 - status_accuracy: 0.9988 - val_loss: 33646.8086 - val_status_accuracy: 0.9960
# Epoch 158/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 12177.9219 - status_accuracy: 0.9986 - val_loss: 33376.3633 - val_status_accuracy: 0.9965
# Epoch 159/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13216.6689 - status_accuracy: 0.9986 - val_loss: 33112.5273 - val_status_accuracy: 0.9965
# Epoch 160/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13110.0986 - status_accuracy: 0.9986 - val_loss: 33585.3594 - val_status_accuracy: 0.9962
# Epoch 161/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 12966.2627 - status_accuracy: 0.9980 - val_loss: 33491.0859 - val_status_accuracy: 0.9735
# Epoch 162/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14302.0586 - status_accuracy: 0.9977 - val_loss: 33279.8594 - val_status_accuracy: 0.9959
# Epoch 163/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 13689.6250 - status_accuracy: 0.9982 - val_loss: 33144.9258 - val_status_accuracy: 0.9956
# Epoch 164/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 12768.7363 - status_accuracy: 0.9979 - val_loss: 33526.3711 - val_status_accuracy: 0.9963
# Epoch 165/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 12890.4268 - status_accuracy: 0.9979 - val_loss: 33328.6680 - val_status_accuracy: 0.9959
# Epoch 166/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 13037.4648 - status_accuracy: 0.9984 - val_loss: 34822.1562 - val_status_accuracy: 0.9965
# Epoch 167/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 14173.5527 - status_accuracy: 0.9987 - val_loss: 33847.6680 - val_status_accuracy: 0.9868
# Epoch 168/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 13574.8516 - status_accuracy: 0.9982 - val_loss: 33224.7383 - val_status_accuracy: 0.9956
# Epoch 169/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 13991.8418 - status_accuracy: 0.9982 - val_loss: 33430.9648 - val_status_accuracy: 0.9970
# Epoch 170/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14560.3232 - status_accuracy: 0.9982 - val_loss: 33730.8203 - val_status_accuracy: 0.9960
# Epoch 171/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14436.1943 - status_accuracy: 0.9982 - val_loss: 33826.2422 - val_status_accuracy: 0.9967
# Epoch 172/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14814.6182 - status_accuracy: 0.9974 - val_loss: 34572.4062 - val_status_accuracy: 0.9960
# Epoch 173/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 13706.6416 - status_accuracy: 0.9978 - val_loss: 33309.0000 - val_status_accuracy: 0.9956
# Epoch 174/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14204.7812 - status_accuracy: 0.9980 - val_loss: 33773.1680 - val_status_accuracy: 0.9963
# Epoch 175/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 14546.1514 - status_accuracy: 0.9985 - val_loss: 33835.6406 - val_status_accuracy: 0.9967
# Epoch 176/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 13598.1426 - status_accuracy: 0.9981 - val_loss: 34112.6953 - val_status_accuracy: 0.9970
# Epoch 177/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14634.2041 - status_accuracy: 0.9976 - val_loss: 33357.0977 - val_status_accuracy: 0.9971
# Epoch 178/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 13984.2520 - status_accuracy: 0.9983 - val_loss: 34147.3906 - val_status_accuracy: 0.9959
# Epoch 179/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13188.4268 - status_accuracy: 0.9984 - val_loss: 33202.9922 - val_status_accuracy: 0.9967
# Epoch 180/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14613.6328 - status_accuracy: 0.9979 - val_loss: 34852.0664 - val_status_accuracy: 0.9971
# Epoch 181/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 13537.4551 - status_accuracy: 0.9985 - val_loss: 33175.6641 - val_status_accuracy: 0.9970
# Epoch 182/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 12376.4463 - status_accuracy: 0.9990 - val_loss: 33722.5391 - val_status_accuracy: 0.9954
# Epoch 183/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 11872.9688 - status_accuracy: 0.9987 - val_loss: 33017.7344 - val_status_accuracy: 0.9950
# Epoch 184/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14933.3672 - status_accuracy: 0.9977 - val_loss: 33399.5391 - val_status_accuracy: 0.9945
# Epoch 185/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13619.3438 - status_accuracy: 0.9982 - val_loss: 33369.5898 - val_status_accuracy: 0.9962
# Epoch 186/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13300.4180 - status_accuracy: 0.9985 - val_loss: 33953.0820 - val_status_accuracy: 0.9965
# Epoch 187/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 13071.6426 - status_accuracy: 0.9978 - val_loss: 33998.8984 - val_status_accuracy: 0.9967
# Epoch 188/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13740.8740 - status_accuracy: 0.9985 - val_loss: 33744.9648 - val_status_accuracy: 0.9938
# Epoch 189/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 13827.9551 - status_accuracy: 0.9984 - val_loss: 33627.3516 - val_status_accuracy: 0.9962
# Epoch 190/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 14464.5557 - status_accuracy: 0.9983 - val_loss: 33964.2422 - val_status_accuracy: 0.9953
# Epoch 191/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 14415.4102 - status_accuracy: 0.9981 - val_loss: 34335.0156 - val_status_accuracy: 0.9959
# Epoch 192/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 12867.4473 - status_accuracy: 0.9983 - val_loss: 34820.3320 - val_status_accuracy: 0.9960
# Epoch 193/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 13452.8535 - status_accuracy: 0.9984 - val_loss: 33324.8438 - val_status_accuracy: 0.9962
# Epoch 194/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 12276.1670 - status_accuracy: 0.9987 - val_loss: 35932.1641 - val_status_accuracy: 0.9960
# Epoch 195/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 14065.0762 - status_accuracy: 0.9985 - val_loss: 34074.4961 - val_status_accuracy: 0.9965
# Epoch 196/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 14213.6855 - status_accuracy: 0.9983 - val_loss: 33913.0742 - val_status_accuracy: 0.9960
# Epoch 197/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 15069.5986 - status_accuracy: 0.9978 - val_loss: 33648.3594 - val_status_accuracy: 0.9962
# Epoch 198/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13580.5410 - status_accuracy: 0.9986 - val_loss: 33304.4688 - val_status_accuracy: 0.9919
# Epoch 199/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 13639.1768 - status_accuracy: 0.9977 - val_loss: 34160.9844 - val_status_accuracy: 0.9967
# Epoch 200/200
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 13050.7412 - status_accuracy: 0.9977 - val_loss: 33582.7422 - val_status_accuracy: 0.9963
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33889.1211 - status_accuracy: 0.9972
# Evaluation Results:
# Total Loss: 33582.7421875
# Survival Loss: 0.9963481426239014
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-0b18129559c2> in <cell line: 142>()
#     140 print(f"Total Loss: {results[0]}")
#     141 print(f"Survival Loss: {results[1]}")
# --> 142 print(f"Status Loss: {results[2]}")
#     143 print(f"Status Accuracy: {results[3]}")
#     144
#
# IndexError: list index out of range
